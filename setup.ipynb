# %% [markdown]
# # Setup Resonance Search

# %% [markdown]
# ### Imports

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import logging
import numpy as np
import matplotlib, itertools
from matplotlib import pyplot as plt

from madminer.core import MadMiner

# MadMiner output
logging.basicConfig(
    format='%(asctime)-5.5s %(name)-20.20s %(levelname)-7.7s %(message)s',
    datefmt='%H:%M',
    level=logging.INFO
)

# Output of all other modules (e.g. matplotlib)
for key in logging.Logger.manager.loggerDict:
    if "madminer" not in key:
        logging.getLogger(key).setLevel(logging.WARNING)

# %% [markdown]
# ### Parameters

# %% [markdown]
# Defines theory parameters as well as the range we search over. Currently:
#
# $M_{Z'}\in [275, 325]$
#
# $g_{Z'}\in [0, 5.]$
#
# The dminputs block looks like:
#
# BLOCK dminputs:
#
#     1   gz    x.xxxxe+xx      # I don't really know what this coupling is; maybe Z' coupling to dark Higgs?
#
#     2   gzu   x.xxxxe+xx      # Z' coupling to up type quarks
#
#     3   gzd   x.xxxxe+xx      # Z' coupling to down type quarks
#
#     4   gzl   x.xxxxe+xx      # Z' coupling to leptons
#
# For testing, we just do u u~ > u u~, so the only relevant coupling is gzu (id=2). Ideally, for full process p p > j j, we would be able to change gzu and gzd simulatenously.
#
# We choose an 11x11 grid in the space as our benchmark points.

# %%
mzp_range = (700., 800.)
gzp_range = (0., 2.)

miner = MadMiner()

miner.add_parameter(
    lha_block='mass',
    lha_id=56,
    parameter_name='mzp',
    morphing_max_power=0,
    parameter_range=mzp_range
)
miner.add_parameter(
    lha_block='dminputs',
    lha_id=2,
    parameter_name='gzp',
    morphing_max_power=0,
    parameter_range=gzp_range
)

m_length = 11
g_length = 11

mzp_arr = np.linspace(mzp_range[0], mzp_range[1], m_length)
gzp_arr = np.linspace(gzp_range[0], gzp_range[1], g_length)
benchmark_pts = [[{'mzp': m, 'gzp': g} for g in gzp_arr] for m in mzp_arr]

for i in range(m_length):
    for j in range(g_length):
        miner.add_benchmark(benchmark_pts[i][j])

miner.save('meta/setup_ppjj_largem.h5')
# Out:
# 22:38 madminer.core        INFO    Added parameter mzp (LHA: mass 56, maximal power in squared ME: (0,), range: (700.0, 800.0))
# 22:38 madminer.core        INFO    Added parameter gzp (LHA: dminputs 2, maximal power in squared ME: (0,), range: (0.0, 2.0))
# 22:38 madminer.core        INFO    Added benchmark benchmark_0: mzp = 7.00e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_1: mzp = 7.00e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_2: mzp = 7.00e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_3: mzp = 7.00e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_4: mzp = 7.00e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_5: mzp = 7.00e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_6: mzp = 7.00e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_7: mzp = 7.00e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_8: mzp = 7.00e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_9: mzp = 7.00e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_10: mzp = 7.00e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_11: mzp = 7.10e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_12: mzp = 7.10e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_13: mzp = 7.10e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_14: mzp = 7.10e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_15: mzp = 7.10e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_16: mzp = 7.10e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_17: mzp = 7.10e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_18: mzp = 7.10e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_19: mzp = 7.10e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_20: mzp = 7.10e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_21: mzp = 7.10e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_22: mzp = 7.20e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_23: mzp = 7.20e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_24: mzp = 7.20e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_25: mzp = 7.20e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_26: mzp = 7.20e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_27: mzp = 7.20e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_28: mzp = 7.20e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_29: mzp = 7.20e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_30: mzp = 7.20e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_31: mzp = 7.20e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_32: mzp = 7.20e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_33: mzp = 7.30e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_34: mzp = 7.30e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_35: mzp = 7.30e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_36: mzp = 7.30e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_37: mzp = 7.30e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_38: mzp = 7.30e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_39: mzp = 7.30e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_40: mzp = 7.30e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_41: mzp = 7.30e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_42: mzp = 7.30e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_43: mzp = 7.30e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_44: mzp = 7.40e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_45: mzp = 7.40e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_46: mzp = 7.40e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_47: mzp = 7.40e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_48: mzp = 7.40e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_49: mzp = 7.40e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_50: mzp = 7.40e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_51: mzp = 7.40e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_52: mzp = 7.40e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_53: mzp = 7.40e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_54: mzp = 7.40e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_55: mzp = 7.50e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_56: mzp = 7.50e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_57: mzp = 7.50e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_58: mzp = 7.50e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_59: mzp = 7.50e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_60: mzp = 7.50e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_61: mzp = 7.50e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_62: mzp = 7.50e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_63: mzp = 7.50e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_64: mzp = 7.50e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_65: mzp = 7.50e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_66: mzp = 7.60e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_67: mzp = 7.60e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_68: mzp = 7.60e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_69: mzp = 7.60e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_70: mzp = 7.60e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_71: mzp = 7.60e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_72: mzp = 7.60e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_73: mzp = 7.60e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_74: mzp = 7.60e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_75: mzp = 7.60e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_76: mzp = 7.60e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_77: mzp = 7.70e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_78: mzp = 7.70e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_79: mzp = 7.70e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_80: mzp = 7.70e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_81: mzp = 7.70e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_82: mzp = 7.70e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_83: mzp = 7.70e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_84: mzp = 7.70e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_85: mzp = 7.70e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_86: mzp = 7.70e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_87: mzp = 7.70e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_88: mzp = 7.80e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_89: mzp = 7.80e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_90: mzp = 7.80e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_91: mzp = 7.80e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_92: mzp = 7.80e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_93: mzp = 7.80e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_94: mzp = 7.80e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_95: mzp = 7.80e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_96: mzp = 7.80e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_97: mzp = 7.80e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_98: mzp = 7.80e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_99: mzp = 7.90e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_100: mzp = 7.90e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_101: mzp = 7.90e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_102: mzp = 7.90e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_103: mzp = 7.90e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_104: mzp = 7.90e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_105: mzp = 7.90e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_106: mzp = 7.90e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_107: mzp = 7.90e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_108: mzp = 7.90e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_109: mzp = 7.90e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_110: mzp = 8.00e+02, gzp = 0.00e+00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_111: mzp = 8.00e+02, gzp = 0.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_112: mzp = 8.00e+02, gzp = 0.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_113: mzp = 8.00e+02, gzp = 0.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_114: mzp = 8.00e+02, gzp = 0.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_115: mzp = 8.00e+02, gzp = 1.00)
# 22:38 madminer.core        INFO    Added benchmark benchmark_116: mzp = 8.00e+02, gzp = 1.20)
# 22:38 madminer.core        INFO    Added benchmark benchmark_117: mzp = 8.00e+02, gzp = 1.40)
# 22:38 madminer.core        INFO    Added benchmark benchmark_118: mzp = 8.00e+02, gzp = 1.60)
# 22:38 madminer.core        INFO    Added benchmark benchmark_119: mzp = 8.00e+02, gzp = 1.80)
# 22:38 madminer.core        INFO    Added benchmark benchmark_120: mzp = 8.00e+02, gzp = 2.00)
# 22:38 madminer.core        INFO    Saving setup (without morphing) to meta/setup_ppjj_largem.h5
